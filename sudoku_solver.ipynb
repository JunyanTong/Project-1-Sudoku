# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import scipy.sparse as scs # sparse matrix construction 
import scipy.linalg as scl # linear algebra algorithms
import scipy.optimize as sco # for minimization use
import matplotlib.pylab as plt # for visualization
from cvxopt import solvers, matrix
import time


def solver(path_name):

    # In the following, the fixed_constraints are constructed from the board directly. 
    def fixed_constraints(N=9):
        rowC = np.zeros(N)
        rowC[0] =1
        rowR = np.zeros(N)
        rowR[0] =1
        row = scl.toeplitz(rowC, rowR)
        ROW = np.kron(row, np.kron(np.ones((1,N)), np.eye(N)))

        colR = np.kron(np.ones((1,N)), rowC)
        col  = scl.toeplitz(rowC, colR)
        COL  = np.kron(col, np.eye(N))

        M = int(np.sqrt(N))
        boxC = np.zeros(M)
        boxC[0]=1
        boxR = np.kron(np.ones((1, M)), boxC) 
        box = scl.toeplitz(boxC, boxR)
        box = np.kron(np.eye(M), box)
        BOX = np.kron(box, np.block([np.eye(N), np.eye(N) ,np.eye(N)]))

        cell = np.eye(N**2)
        CELL = np.kron(cell, np.ones((1,N)))

        return scs.csr_matrix(np.block([[ROW],[COL],[BOX],[CELL]]))

    # For the constraint from clues, we extract the nonzeros from the quiz string.
    def clue_constraint(input_quiz, N=9):
        m = np.reshape([int(c) for c in input_quiz], (N,N))
        r, c = np.where(m.T)
        v = np.array([m[c[d],r[d]] for d in range(len(r))])

        table = N * c + r
        table = np.block([[table],[v-1]])

        # it is faster to use lil_matrix when changing the sparse structure.
        CLUE = scs.lil_matrix((len(table.T), N**3))
        for i in range(len(table.T)):
            CLUE[i,table[0,i]*N + table[1,i]] = 1
        # change back to csr_matrix.
        CLUE = CLUE.tocsr() 

        return CLUE
    
    data=pd.read_csv(path_name) 
    solvers.options['show_progress'] = False
    corr_cnt = 0
    start = time.time()
    random_seed = 42
    np.random.seed(random_seed)


    corr_cnt = 0
    start = time.time()
    
    if len(data) > 1000:
        samples = np.random.choice(len(data), 1000)
    else:
        samples = range(len(data))     
    
    for i in range(len(samples)):
        quiz = data["quizzes"][samples[i]]
        solu = data["solutions"][samples[i]]
        A0 = fixed_constraints()
        A1 = clue_constraint(quiz)

        # Formulate the matrix A and vector B (B is all ones).
        A = scs.vstack((A0,A1))
        A = A.toarray()
        B = np.ones(A.shape[0])
        # Because rank defficiency. We need to extract effective rank.
        u, s, vh = np.linalg.svd(A, full_matrices=False)
        K = np.sum(s > 1e-12)
        S_ = np.block([np.diag(s[:K]), np.zeros((K, A.shape[0]-K))])
        A = S_@vh
        B = u.T@B
        B = B[:K]

        c = matrix(np.block([ np.ones(A.shape[1]), np.ones(A.shape[1]) ]))
        G = matrix(np.block([[-np.eye(A.shape[1]), np.zeros((A.shape[1], A.shape[1]))],\
                             [np.zeros((A.shape[1], A.shape[1])), -np.eye(A.shape[1])]]))
        h = matrix(np.zeros(A.shape[1]*2))
        H = matrix(np.block([A, -A]))
        b = matrix(B)

        sol = solvers.lp(c,G,h,H,b)

        # postprocessing the solution
        X = np.array(sol['x']).T[0]
        x = X[:A.shape[1]] - X[A.shape[1]:]

        # map to board
        z = np.reshape(x, (81, 9))
        if np.linalg.norm(np.reshape(np.array([np.argmax(d)+1 for d in z]), (9,9) ) \
                          - np.reshape([int(c) for c in solu], (9,9)), np.inf) >0:
            pass
        else:
            #print("CORRECT")
            corr_cnt += 1
        if (i+1) % 5 == 0:
            end = time.time()
            print("Aver Time: {t:6.2f} secs. Success rate: {corr} / {all} ".format(t=(end-start)/(i+1), corr=corr_cnt, all=i+1) )

    end = time.time()
    print("Aver Time: {t:6.2f} secs. Success rate: {corr} / {all} ".format(t=(end-start)/(i+1), corr=corr_cnt, all=i+1) )
    return corr_cnt/(i+1)

# %%
path1="C:/Users/Junya/Desktop/Math110B/Project1/Project-1-Sudoku/input/small1.csv"

# %%
solver(path1)
# Out:
# Aver Time:   1.09 secs. Success rate: 5 / 5
# Aver Time:   1.15 secs. Success rate: 10 / 10
# Aver Time:   1.20 secs. Success rate: 15 / 15
# Aver Time:   1.21 secs. Success rate: 20 / 20
# Aver Time:   1.20 secs. Success rate: 24 / 24
# 1.0

# %%
path3="C:/Users/Junya/Desktop/Math110B/Project1/Project-1-Sudoku/input/large1.csv"

# %%
solver(path3)
# Out:
# Aver Time:   1.40 secs. Success rate: 3 / 5
# Aver Time:   1.34 secs. Success rate: 7 / 10
# Aver Time:   1.35 secs. Success rate: 12 / 15
# Aver Time:   1.32 secs. Success rate: 16 / 20
# Aver Time:   1.30 secs. Success rate: 20 / 25
# Aver Time:   1.33 secs. Success rate: 24 / 30
# Aver Time:   1.36 secs. Success rate: 28 / 35
# Aver Time:   1.39 secs. Success rate: 32 / 40
# Aver Time:   1.40 secs. Success rate: 36 / 45
# Aver Time:   1.39 secs. Success rate: 40 / 50
# Aver Time:   1.39 secs. Success rate: 43 / 55
# Aver Time:   1.39 secs. Success rate: 47 / 60
# Aver Time:   1.38 secs. Success rate: 51 / 65
# Aver Time:   1.39 secs. Success rate: 56 / 70
# Aver Time:   1.39 secs. Success rate: 59 / 75
# Aver Time:   1.40 secs. Success rate: 64 / 80
# Aver Time:   1.40 secs. Success rate: 68 / 85
# Aver Time:   1.39 secs. Success rate: 70 / 90
# Aver Time:   1.39 secs. Success rate: 74 / 95
# Aver Time:   1.39 secs. Success rate: 78 / 100
# Aver Time:   1.38 secs. Success rate: 82 / 105
# Aver Time:   1.38 secs. Success rate: 85 / 110
# Aver Time:   1.38 secs. Success rate: 88 / 115
# Aver Time:   1.38 secs. Success rate: 92 / 120
# Aver Time:   1.37 secs. Success rate: 96 / 125
# Aver Time:   1.37 secs. Success rate: 100 / 130
# Aver Time:   1.37 secs. Success rate: 103 / 135
# Aver Time:   1.37 secs. Success rate: 107 / 140
# Aver Time:   1.36 secs. Success rate: 110 / 145
# Aver Time:   1.36 secs. Success rate: 115 / 150
# Aver Time:   1.36 secs. Success rate: 120 / 155
# Aver Time:   1.36 secs. Success rate: 124 / 160
# Aver Time:   1.36 secs. Success rate: 127 / 165
# Aver Time:   1.36 secs. Success rate: 129 / 170
# Aver Time:   1.36 secs. Success rate: 134 / 175
# Aver Time:   1.36 secs. Success rate: 138 / 180
# Aver Time:   1.36 secs. Success rate: 142 / 185
# Aver Time:   1.36 secs. Success rate: 145 / 190
# Aver Time:   1.36 secs. Success rate: 150 / 195
# Aver Time:   1.36 secs. Success rate: 155 / 200
# Aver Time:   1.36 secs. Success rate: 159 / 205
# Aver Time:   1.36 secs. Success rate: 164 / 210
# Aver Time:   1.36 secs. Success rate: 169 / 215
# Aver Time:   1.36 secs. Success rate: 173 / 220
# Aver Time:   1.36 secs. Success rate: 178 / 225
# Aver Time:   1.36 secs. Success rate: 182 / 230
# Aver Time:   1.36 secs. Success rate: 187 / 235
# Aver Time:   1.36 secs. Success rate: 191 / 240
# Aver Time:   1.36 secs. Success rate: 195 / 245
# Aver Time:   1.37 secs. Success rate: 200 / 250
# Aver Time:   1.37 secs. Success rate: 203 / 255
# Aver Time:   1.37 secs. Success rate: 208 / 260
# Aver Time:   1.37 secs. Success rate: 211 / 265
# Aver Time:   1.37 secs. Success rate: 215 / 270
# Aver Time:   1.37 secs. Success rate: 219 / 275
# Aver Time:   1.37 secs. Success rate: 224 / 280
# Aver Time:   1.37 secs. Success rate: 229 / 285
# Aver Time:   1.37 secs. Success rate: 233 / 290
# Aver Time:   1.37 secs. Success rate: 237 / 295
# Aver Time:   1.37 secs. Success rate: 242 / 300
# Aver Time:   1.37 secs. Success rate: 245 / 305
# Aver Time:   1.37 secs. Success rate: 249 / 310
# Aver Time:   1.37 secs. Success rate: 253 / 315
# Aver Time:   1.36 secs. Success rate: 257 / 320
# Aver Time:   1.36 secs. Success rate: 261 / 325
# Aver Time:   1.36 secs. Success rate: 266 / 330
# Aver Time:   1.36 secs. Success rate: 270 / 335
# Aver Time:   1.36 secs. Success rate: 275 / 340
# Aver Time:   1.36 secs. Success rate: 280 / 345
# Aver Time:   1.36 secs. Success rate: 283 / 350
# Aver Time:   1.36 secs. Success rate: 288 / 355
# Aver Time:   1.36 secs. Success rate: 291 / 360
# Aver Time:   1.36 secs. Success rate: 295 / 365
# Aver Time:   1.36 secs. Success rate: 300 / 370
# Aver Time:   1.36 secs. Success rate: 304 / 375
# Aver Time:   1.36 secs. Success rate: 308 / 380
# Aver Time:   1.36 secs. Success rate: 313 / 385
# Aver Time:   1.36 secs. Success rate: 318 / 390
# Aver Time:   1.36 secs. Success rate: 323 / 395
# Aver Time:   1.35 secs. Success rate: 328 / 400
# Aver Time:   1.36 secs. Success rate: 333 / 405
# Aver Time:   1.35 secs. Success rate: 337 / 410
# Aver Time:   1.35 secs. Success rate: 340 / 415
# Aver Time:   1.35 secs. Success rate: 344 / 420
# Aver Time:   1.35 secs. Success rate: 348 / 425
# Aver Time:   1.35 secs. Success rate: 353 / 430
# Aver Time:   1.35 secs. Success rate: 356 / 435
# Aver Time:   1.35 secs. Success rate: 358 / 440
# Aver Time:   1.35 secs. Success rate: 363 / 445
# Aver Time:   1.35 secs. Success rate: 367 / 450
# Aver Time:   1.35 secs. Success rate: 371 / 455
# Aver Time:   1.35 secs. Success rate: 375 / 460
# Aver Time:   1.35 secs. Success rate: 378 / 465
# Aver Time:   1.35 secs. Success rate: 383 / 470
# Aver Time:   1.36 secs. Success rate: 387 / 475
# Aver Time:   1.36 secs. Success rate: 392 / 480
# Aver Time:   1.36 secs. Success rate: 396 / 485
# Aver Time:   1.36 secs. Success rate: 400 / 490
# Aver Time:   1.36 secs. Success rate: 405 / 495
# Aver Time:   1.36 secs. Success rate: 410 / 500
# Aver Time:   1.36 secs. Success rate: 413 / 505
# Aver Time:   1.36 secs. Success rate: 418 / 510
# Aver Time:   1.36 secs. Success rate: 422 / 515
# Aver Time:   1.36 secs. Success rate: 425 / 520
# Aver Time:   1.36 secs. Success rate: 430 / 525
# Aver Time:   1.36 secs. Success rate: 433 / 530
# Aver Time:   1.36 secs. Success rate: 436 / 535
# Aver Time:   1.35 secs. Success rate: 441 / 540
# Aver Time:   1.35 secs. Success rate: 445 / 545
# Aver Time:   1.35 secs. Success rate: 448 / 550
# Aver Time:   1.35 secs. Success rate: 452 / 555
# Aver Time:   1.35 secs. Success rate: 456 / 560
# Aver Time:   1.35 secs. Success rate: 460 / 565
# Aver Time:   1.35 secs. Success rate: 465 / 570
# Aver Time:   1.35 secs. Success rate: 470 / 575
# Aver Time:   1.35 secs. Success rate: 474 / 580
# Aver Time:   1.35 secs. Success rate: 479 / 585
# Aver Time:   1.35 secs. Success rate: 483 / 590
# Aver Time:   1.36 secs. Success rate: 488 / 595
# Aver Time:   1.36 secs. Success rate: 492 / 600
# Aver Time:   1.36 secs. Success rate: 496 / 605
# Aver Time:   1.36 secs. Success rate: 500 / 610
# Aver Time:   1.36 secs. Success rate: 503 / 615
# Aver Time:   1.36 secs. Success rate: 507 / 620
# Aver Time:   1.36 secs. Success rate: 512 / 625
# Aver Time:   1.36 secs. Success rate: 517 / 630
# Aver Time:   1.36 secs. Success rate: 521 / 635
# Aver Time:   1.36 secs. Success rate: 524 / 640
# Aver Time:   1.36 secs. Success rate: 529 / 645
# Aver Time:   1.36 secs. Success rate: 534 / 650
# Aver Time:   1.36 secs. Success rate: 536 / 655
# Aver Time:   1.36 secs. Success rate: 540 / 660
# Aver Time:   1.36 secs. Success rate: 544 / 665
# Aver Time:   1.36 secs. Success rate: 548 / 670
# Aver Time:   1.36 secs. Success rate: 552 / 675
# Aver Time:   1.37 secs. Success rate: 556 / 680
# Aver Time:   1.37 secs. Success rate: 561 / 685
# Aver Time:   1.37 secs. Success rate: 566 / 690
# Aver Time:   1.37 secs. Success rate: 571 / 695
# Aver Time:   1.37 secs. Success rate: 573 / 700
# Aver Time:   1.37 secs. Success rate: 577 / 705
# Aver Time:   1.37 secs. Success rate: 582 / 710
# Aver Time:   1.37 secs. Success rate: 586 / 715
# Aver Time:   1.37 secs. Success rate: 591 / 720
# Aver Time:   1.37 secs. Success rate: 596 / 725
# Aver Time:   1.37 secs. Success rate: 598 / 730
# Aver Time:   1.37 secs. Success rate: 602 / 735
# Aver Time:   1.38 secs. Success rate: 606 / 740
# Aver Time:   1.38 secs. Success rate: 610 / 745
# Aver Time:   1.38 secs. Success rate: 615 / 750
# Aver Time:   1.38 secs. Success rate: 620 / 755
# Aver Time:   1.38 secs. Success rate: 623 / 760
# Aver Time:   1.38 secs. Success rate: 626 / 765
# Aver Time:   1.38 secs. Success rate: 628 / 770
# Aver Time:   1.38 secs. Success rate: 632 / 775
# Aver Time:   1.38 secs. Success rate: 636 / 780
# Aver Time:   1.38 secs. Success rate: 639 / 785
# Aver Time:   1.38 secs. Success rate: 643 / 790
# Aver Time:   1.38 secs. Success rate: 648 / 795
# Aver Time:   1.38 secs. Success rate: 653 / 800
# Aver Time:   1.38 secs. Success rate: 657 / 805
# Aver Time:   1.38 secs. Success rate: 660 / 810
# Aver Time:   1.38 secs. Success rate: 663 / 815
# Aver Time:   1.38 secs. Success rate: 667 / 820
# Aver Time:   1.38 secs. Success rate: 671 / 825
# Aver Time:   1.38 secs. Success rate: 676 / 830
# Aver Time:   1.38 secs. Success rate: 681 / 835
# Aver Time:   1.38 secs. Success rate: 683 / 840
# Aver Time:   1.38 secs. Success rate: 688 / 845
# Aver Time:   1.38 secs. Success rate: 693 / 850
# Aver Time:   1.38 secs. Success rate: 697 / 855
# Aver Time:   1.38 secs. Success rate: 701 / 860
# Aver Time:   1.38 secs. Success rate: 706 / 865
# Aver Time:   1.38 secs. Success rate: 711 / 870
# Aver Time:   1.39 secs. Success rate: 715 / 875
# Aver Time:   1.38 secs. Success rate: 719 / 880
# Aver Time:   1.38 secs. Success rate: 722 / 885
# Aver Time:   1.38 secs. Success rate: 727 / 890
# Aver Time:   1.38 secs. Success rate: 732 / 895
# Aver Time:   1.38 secs. Success rate: 736 / 900
# Aver Time:   1.38 secs. Success rate: 740 / 905
# Aver Time:   1.38 secs. Success rate: 744 / 910
# Aver Time:   1.38 secs. Success rate: 749 / 915
# Aver Time:   1.38 secs. Success rate: 752 / 920
# Aver Time:   1.39 secs. Success rate: 757 / 925
# Aver Time:   1.39 secs. Success rate: 758 / 930
# Aver Time:   1.39 secs. Success rate: 763 / 935
# Aver Time:   1.39 secs. Success rate: 767 / 940
# Aver Time:   1.39 secs. Success rate: 771 / 945
# Aver Time:   1.39 secs. Success rate: 776 / 950
# Aver Time:   1.39 secs. Success rate: 781 / 955
# Aver Time:   1.39 secs. Success rate: 786 / 960
# Aver Time:   1.39 secs. Success rate: 791 / 965
# Aver Time:   1.39 secs. Success rate: 795 / 970
# Aver Time:   1.39 secs. Success rate: 799 / 975
# Aver Time:   1.39 secs. Success rate: 803 / 980
# Aver Time:   1.39 secs. Success rate: 807 / 985
# Aver Time:   1.39 secs. Success rate: 810 / 990
# Aver Time:   1.39 secs. Success rate: 814 / 995
# Aver Time:   1.39 secs. Success rate: 818 / 1000
# Aver Time:   1.39 secs. Success rate: 818 / 1000
# 0.818

# %%
path2="C:/Users/Junya/Desktop/Math110B/Project1/Project-1-Sudoku/input/small2.csv"

# %%
solver(path2)
# Out:
# Aver Time:   1.39 secs. Success rate: 2 / 5
# Aver Time:   1.36 secs. Success rate: 3 / 10
# Aver Time:   1.35 secs. Success rate: 4 / 15
# Aver Time:   1.34 secs. Success rate: 5 / 20
# Aver Time:   1.32 secs. Success rate: 7 / 25
# Aver Time:   1.30 secs. Success rate: 7 / 30
# Aver Time:   1.29 secs. Success rate: 8 / 35
# Aver Time:   1.28 secs. Success rate: 11 / 40
# Aver Time:   1.28 secs. Success rate: 14 / 45
# Aver Time:   1.29 secs. Success rate: 14 / 50
# Aver Time:   1.30 secs. Success rate: 14 / 55
# Aver Time:   1.30 secs. Success rate: 15 / 60
# Aver Time:   1.31 secs. Success rate: 19 / 65
# Aver Time:   1.31 secs. Success rate: 22 / 70
# Aver Time:   1.31 secs. Success rate: 23 / 75
# Aver Time:   1.30 secs. Success rate: 25 / 80
# Aver Time:   1.31 secs. Success rate: 29 / 85
# Aver Time:   1.31 secs. Success rate: 30 / 90
# Aver Time:   1.31 secs. Success rate: 33 / 95
# Aver Time:   1.31 secs. Success rate: 35 / 100
# Aver Time:   1.31 secs. Success rate: 37 / 105
# Aver Time:   1.31 secs. Success rate: 39 / 110
# Aver Time:   1.31 secs. Success rate: 41 / 115
# Aver Time:   1.31 secs. Success rate: 44 / 120
# Aver Time:   1.31 secs. Success rate: 46 / 125
# Aver Time:   1.31 secs. Success rate: 48 / 130
# Aver Time:   1.31 secs. Success rate: 52 / 135
# Aver Time:   1.31 secs. Success rate: 54 / 140
# Aver Time:   1.31 secs. Success rate: 56 / 145
# Aver Time:   1.31 secs. Success rate: 56 / 150
# Aver Time:   1.31 secs. Success rate: 58 / 155
# Aver Time:   1.31 secs. Success rate: 61 / 160
# Aver Time:   1.31 secs. Success rate: 65 / 165
# Aver Time:   1.31 secs. Success rate: 66 / 170
# Aver Time:   1.31 secs. Success rate: 66 / 175
# Aver Time:   1.31 secs. Success rate: 70 / 180
# Aver Time:   1.31 secs. Success rate: 73 / 185
# Aver Time:   1.31 secs. Success rate: 77 / 190
# Aver Time:   1.31 secs. Success rate: 77 / 195
# Aver Time:   1.31 secs. Success rate: 80 / 200
# Aver Time:   1.31 secs. Success rate: 81 / 205
# Aver Time:   1.31 secs. Success rate: 83 / 210
# Aver Time:   1.31 secs. Success rate: 87 / 215
# Aver Time:   1.31 secs. Success rate: 89 / 220
# Aver Time:   1.31 secs. Success rate: 90 / 225
# Aver Time:   1.31 secs. Success rate: 91 / 230
# Aver Time:   1.31 secs. Success rate: 91 / 235
# Aver Time:   1.31 secs. Success rate: 92 / 240
# Aver Time:   1.31 secs. Success rate: 93 / 245
# Aver Time:   1.31 secs. Success rate: 93 / 250
# Aver Time:   1.31 secs. Success rate: 96 / 255
# Aver Time:   1.31 secs. Success rate: 97 / 260
# Aver Time:   1.31 secs. Success rate: 99 / 265
# Aver Time:   1.31 secs. Success rate: 100 / 270
# Aver Time:   1.31 secs. Success rate: 101 / 275
# Aver Time:   1.31 secs. Success rate: 101 / 280
# Aver Time:   1.31 secs. Success rate: 103 / 285
# Aver Time:   1.31 secs. Success rate: 105 / 290
# Aver Time:   1.31 secs. Success rate: 107 / 295
# Aver Time:   1.31 secs. Success rate: 108 / 300
# Aver Time:   1.31 secs. Success rate: 109 / 305
# Aver Time:   1.31 secs. Success rate: 112 / 310
# Aver Time:   1.31 secs. Success rate: 114 / 315
# Aver Time:   1.31 secs. Success rate: 114 / 320
# Aver Time:   1.31 secs. Success rate: 115 / 325
# Aver Time:   1.31 secs. Success rate: 119 / 330
# Aver Time:   1.31 secs. Success rate: 120 / 335
# Aver Time:   1.31 secs. Success rate: 122 / 340
# Aver Time:   1.31 secs. Success rate: 123 / 345
# Aver Time:   1.31 secs. Success rate: 124 / 350
# Aver Time:   1.31 secs. Success rate: 125 / 355
# Aver Time:   1.31 secs. Success rate: 127 / 360
# Aver Time:   1.31 secs. Success rate: 128 / 365
# Aver Time:   1.31 secs. Success rate: 130 / 370
# Aver Time:   1.31 secs. Success rate: 132 / 375
# Aver Time:   1.31 secs. Success rate: 136 / 380
# Aver Time:   1.31 secs. Success rate: 137 / 385
# Aver Time:   1.31 secs. Success rate: 139 / 390
# Aver Time:   1.31 secs. Success rate: 141 / 395
# Aver Time:   1.31 secs. Success rate: 144 / 400
# Aver Time:   1.31 secs. Success rate: 145 / 405
# Aver Time:   1.31 secs. Success rate: 146 / 410
# Aver Time:   1.31 secs. Success rate: 148 / 415
# Aver Time:   1.32 secs. Success rate: 150 / 420
# Aver Time:   1.31 secs. Success rate: 151 / 425
# Aver Time:   1.31 secs. Success rate: 154 / 430
# Aver Time:   1.31 secs. Success rate: 155 / 435
# Aver Time:   1.32 secs. Success rate: 155 / 440
# Aver Time:   1.32 secs. Success rate: 157 / 445
# Aver Time:   1.32 secs. Success rate: 158 / 450
# Aver Time:   1.32 secs. Success rate: 159 / 455
# Aver Time:   1.32 secs. Success rate: 161 / 460
# Aver Time:   1.32 secs. Success rate: 163 / 465
# Aver Time:   1.32 secs. Success rate: 165 / 470
# Aver Time:   1.32 secs. Success rate: 167 / 475
# Aver Time:   1.32 secs. Success rate: 168 / 480
# Aver Time:   1.32 secs. Success rate: 171 / 485
# Aver Time:   1.32 secs. Success rate: 172 / 490
# Aver Time:   1.32 secs. Success rate: 173 / 495
# Aver Time:   1.32 secs. Success rate: 176 / 500
# Aver Time:   1.32 secs. Success rate: 178 / 505
# Aver Time:   1.32 secs. Success rate: 182 / 510
# Aver Time:   1.32 secs. Success rate: 183 / 515
# Aver Time:   1.32 secs. Success rate: 184 / 520
# Aver Time:   1.32 secs. Success rate: 185 / 525
# Aver Time:   1.32 secs. Success rate: 187 / 530
# Aver Time:   1.32 secs. Success rate: 188 / 535
# Aver Time:   1.32 secs. Success rate: 188 / 540
# Aver Time:   1.32 secs. Success rate: 193 / 545
# Aver Time:   1.32 secs. Success rate: 193 / 550
# Aver Time:   1.32 secs. Success rate: 196 / 555
# Aver Time:   1.32 secs. Success rate: 199 / 560
# Aver Time:   1.32 secs. Success rate: 200 / 565
# Aver Time:   1.32 secs. Success rate: 201 / 570
# Aver Time:   1.32 secs. Success rate: 203 / 575
# Aver Time:   1.32 secs. Success rate: 204 / 580
# Aver Time:   1.33 secs. Success rate: 206 / 585
# Aver Time:   1.33 secs. Success rate: 208 / 590
# Aver Time:   1.33 secs. Success rate: 210 / 595
# Aver Time:   1.33 secs. Success rate: 210 / 600
# Aver Time:   1.33 secs. Success rate: 212 / 605
# Aver Time:   1.33 secs. Success rate: 214 / 610
# Aver Time:   1.32 secs. Success rate: 215 / 615
# Aver Time:   1.32 secs. Success rate: 217 / 620
# Aver Time:   1.33 secs. Success rate: 219 / 625
# Aver Time:   1.33 secs. Success rate: 222 / 630
# Aver Time:   1.33 secs. Success rate: 223 / 635
# Aver Time:   1.33 secs. Success rate: 224 / 640
# Aver Time:   1.33 secs. Success rate: 225 / 645
# Aver Time:   1.32 secs. Success rate: 225 / 650
# Aver Time:   1.33 secs. Success rate: 226 / 655
# Aver Time:   1.33 secs. Success rate: 228 / 660
# Aver Time:   1.33 secs. Success rate: 231 / 665
# Aver Time:   1.33 secs. Success rate: 233 / 670
# Aver Time:   1.33 secs. Success rate: 234 / 675
# Aver Time:   1.33 secs. Success rate: 236 / 680
# Aver Time:   1.33 secs. Success rate: 238 / 685
# Aver Time:   1.33 secs. Success rate: 239 / 690
# Aver Time:   1.33 secs. Success rate: 241 / 695
# Aver Time:   1.33 secs. Success rate: 243 / 700
# Aver Time:   1.33 secs. Success rate: 243 / 705
# Aver Time:   1.33 secs. Success rate: 244 / 710
# Aver Time:   1.33 secs. Success rate: 245 / 715
# Aver Time:   1.34 secs. Success rate: 247 / 720
# Aver Time:   1.34 secs. Success rate: 248 / 725
# Aver Time:   1.34 secs. Success rate: 250 / 730
# Aver Time:   1.35 secs. Success rate: 254 / 735
# Aver Time:   1.35 secs. Success rate: 254 / 740
# Aver Time:   1.35 secs. Success rate: 256 / 745
# Aver Time:   1.36 secs. Success rate: 259 / 750
# Aver Time:   1.36 secs. Success rate: 260 / 755
# Aver Time:   1.36 secs. Success rate: 260 / 760
# Aver Time:   1.37 secs. Success rate: 262 / 765
# Aver Time:   1.37 secs. Success rate: 263 / 770
# Aver Time:   1.37 secs. Success rate: 263 / 775
# Aver Time:   1.38 secs. Success rate: 265 / 780
# Aver Time:   1.38 secs. Success rate: 266 / 785
# Aver Time:   1.38 secs. Success rate: 267 / 790
# Aver Time:   1.40 secs. Success rate: 269 / 795
# Aver Time:   1.43 secs. Success rate: 270 / 800
# Aver Time:   1.44 secs. Success rate: 273 / 805
# Aver Time:   1.45 secs. Success rate: 275 / 810
# Aver Time:   1.45 secs. Success rate: 278 / 815
# Aver Time:   1.45 secs. Success rate: 279 / 820
# Aver Time:   1.45 secs. Success rate: 280 / 825
# Aver Time:   1.46 secs. Success rate: 284 / 830
# Aver Time:   1.46 secs. Success rate: 286 / 835
# Aver Time:   1.46 secs. Success rate: 287 / 840
# Aver Time:   1.46 secs. Success rate: 288 / 845
# Aver Time:   1.47 secs. Success rate: 289 / 850
# Aver Time:   1.47 secs. Success rate: 291 / 855
# Aver Time:   1.47 secs. Success rate: 293 / 860
# Aver Time:   1.47 secs. Success rate: 295 / 865
# Aver Time:   1.48 secs. Success rate: 295 / 870
# Aver Time:   1.48 secs. Success rate: 298 / 875
# Aver Time:   1.48 secs. Success rate: 299 / 880
# Aver Time:   1.48 secs. Success rate: 300 / 885
# Aver Time:   1.48 secs. Success rate: 301 / 890
# Aver Time:   1.49 secs. Success rate: 302 / 895
# Aver Time:   1.49 secs. Success rate: 303 / 900
# Aver Time:   1.49 secs. Success rate: 303 / 905
# Aver Time:   1.49 secs. Success rate: 303 / 910
# Aver Time:   1.49 secs. Success rate: 303 / 915
# Aver Time:   1.49 secs. Success rate: 303 / 920
# Aver Time:   1.49 secs. Success rate: 306 / 925
# Aver Time:   1.50 secs. Success rate: 308 / 930
# Aver Time:   1.50 secs. Success rate: 309 / 935
# Aver Time:   1.50 secs. Success rate: 310 / 940
# Aver Time:   1.50 secs. Success rate: 312 / 945
# Aver Time:   1.50 secs. Success rate: 315 / 950
# Aver Time:   1.50 secs. Success rate: 315 / 955
# Aver Time:   1.50 secs. Success rate: 316 / 960
# Aver Time:   1.51 secs. Success rate: 318 / 965
# Aver Time:   1.51 secs. Success rate: 319 / 970
# Aver Time:   1.51 secs. Success rate: 320 / 975
# Aver Time:   1.51 secs. Success rate: 320 / 980
# Aver Time:   1.51 secs. Success rate: 322 / 985
# Aver Time:   1.51 secs. Success rate: 323 / 990
# Aver Time:   1.52 secs. Success rate: 323 / 995
# Aver Time:   1.52 secs. Success rate: 324 / 1000
# Aver Time:   1.52 secs. Success rate: 324 / 1000
# 0.324

# %%
path4="C:/Users/Junya/Desktop/Math110B/Project1/Project-1-Sudoku/input/large2.csv"

# %%
solver(path4)
# Out:
# Aver Time:   1.25 secs. Success rate: 5 / 5
# Aver Time:   1.24 secs. Success rate: 10 / 10
# Aver Time:   1.19 secs. Success rate: 15 / 15
# Aver Time:   1.18 secs. Success rate: 20 / 20
# Aver Time:   1.19 secs. Success rate: 25 / 25
# Aver Time:   1.18 secs. Success rate: 30 / 30
# Aver Time:   1.17 secs. Success rate: 35 / 35
# Aver Time:   1.17 secs. Success rate: 40 / 40
# Aver Time:   1.17 secs. Success rate: 45 / 45
# Aver Time:   1.17 secs. Success rate: 50 / 50
# Aver Time:   1.17 secs. Success rate: 55 / 55
# Aver Time:   1.17 secs. Success rate: 60 / 60
# Aver Time:   1.17 secs. Success rate: 65 / 65
# Aver Time:   1.16 secs. Success rate: 70 / 70
# Aver Time:   1.16 secs. Success rate: 75 / 75
# Aver Time:   1.17 secs. Success rate: 80 / 80
# Aver Time:   1.17 secs. Success rate: 85 / 85
# Aver Time:   1.17 secs. Success rate: 90 / 90
# Aver Time:   1.17 secs. Success rate: 95 / 95
# Aver Time:   1.18 secs. Success rate: 100 / 100
# Aver Time:   1.18 secs. Success rate: 105 / 105
# Aver Time:   1.18 secs. Success rate: 110 / 110
# Aver Time:   1.19 secs. Success rate: 115 / 115
# Aver Time:   1.19 secs. Success rate: 120 / 120
# Aver Time:   1.19 secs. Success rate: 125 / 125
# Aver Time:   1.18 secs. Success rate: 130 / 130
# Aver Time:   1.18 secs. Success rate: 135 / 135
# Aver Time:   1.19 secs. Success rate: 140 / 140
# Aver Time:   1.19 secs. Success rate: 145 / 145
# Aver Time:   1.19 secs. Success rate: 150 / 150
# Aver Time:   1.18 secs. Success rate: 155 / 155
# Aver Time:   1.18 secs. Success rate: 160 / 160
# Aver Time:   1.17 secs. Success rate: 165 / 165
# Aver Time:   1.17 secs. Success rate: 170 / 170
# Aver Time:   1.17 secs. Success rate: 175 / 175
# Aver Time:   1.16 secs. Success rate: 180 / 180
# Aver Time:   1.16 secs. Success rate: 185 / 185
# Aver Time:   1.16 secs. Success rate: 190 / 190
# Aver Time:   1.16 secs. Success rate: 195 / 195
# Aver Time:   1.16 secs. Success rate: 200 / 200
# Aver Time:   1.15 secs. Success rate: 205 / 205
# Aver Time:   1.15 secs. Success rate: 210 / 210
# Aver Time:   1.15 secs. Success rate: 215 / 215
# Aver Time:   1.15 secs. Success rate: 220 / 220
# Aver Time:   1.15 secs. Success rate: 225 / 225
# Aver Time:   1.14 secs. Success rate: 230 / 230
# Aver Time:   1.14 secs. Success rate: 235 / 235
# Aver Time:   1.14 secs. Success rate: 240 / 240
# Aver Time:   1.14 secs. Success rate: 245 / 245
# Aver Time:   1.14 secs. Success rate: 250 / 250
# Aver Time:   1.14 secs. Success rate: 255 / 255
# Aver Time:   1.14 secs. Success rate: 260 / 260
# Aver Time:   1.14 secs. Success rate: 265 / 265
# Aver Time:   1.14 secs. Success rate: 270 / 270
# Aver Time:   1.14 secs. Success rate: 275 / 275
# Aver Time:   1.14 secs. Success rate: 280 / 280
# Aver Time:   1.14 secs. Success rate: 285 / 285
# Aver Time:   1.14 secs. Success rate: 290 / 290
# Aver Time:   1.14 secs. Success rate: 295 / 295
# Aver Time:   1.14 secs. Success rate: 300 / 300
# Aver Time:   1.14 secs. Success rate: 305 / 305
# Aver Time:   1.14 secs. Success rate: 310 / 310
# Aver Time:   1.14 secs. Success rate: 315 / 315
# Aver Time:   1.14 secs. Success rate: 320 / 320
# Aver Time:   1.15 secs. Success rate: 325 / 325
# Aver Time:   1.16 secs. Success rate: 330 / 330
# Aver Time:   1.17 secs. Success rate: 335 / 335
# Aver Time:   1.18 secs. Success rate: 340 / 340
# Aver Time:   1.18 secs. Success rate: 345 / 345
# Aver Time:   1.19 secs. Success rate: 350 / 350
# Aver Time:   1.20 secs. Success rate: 355 / 355
# Aver Time:   1.20 secs. Success rate: 360 / 360
# Aver Time:   1.21 secs. Success rate: 365 / 365
# Aver Time:   1.22 secs. Success rate: 370 / 370
# Aver Time:   1.22 secs. Success rate: 375 / 375
# Aver Time:   1.23 secs. Success rate: 380 / 380
# Aver Time:   1.24 secs. Success rate: 385 / 385
# Aver Time:   1.24 secs. Success rate: 390 / 390
# Aver Time:   1.25 secs. Success rate: 395 / 395
# Aver Time:   1.26 secs. Success rate: 400 / 400
# Aver Time:   1.26 secs. Success rate: 405 / 405
# Aver Time:   1.27 secs. Success rate: 410 / 410
# Aver Time:   1.27 secs. Success rate: 415 / 415
# Aver Time:   1.28 secs. Success rate: 420 / 420
# Aver Time:   1.28 secs. Success rate: 425 / 425
# Aver Time:   1.29 secs. Success rate: 430 / 430
# Aver Time:   1.29 secs. Success rate: 435 / 435
# Aver Time:   1.30 secs. Success rate: 440 / 440
# Aver Time:   1.30 secs. Success rate: 445 / 445
# Aver Time:   1.31 secs. Success rate: 450 / 450
# Aver Time:   1.31 secs. Success rate: 455 / 455
# Aver Time:   1.31 secs. Success rate: 460 / 460
# Aver Time:   1.32 secs. Success rate: 465 / 465
# Aver Time:   1.33 secs. Success rate: 470 / 470
# Aver Time:   1.33 secs. Success rate: 475 / 475
# Aver Time:   1.33 secs. Success rate: 480 / 480
# Aver Time:   1.34 secs. Success rate: 485 / 485
# Aver Time:   1.34 secs. Success rate: 490 / 490
# Aver Time:   1.34 secs. Success rate: 495 / 495
# Aver Time:   1.35 secs. Success rate: 500 / 500
# Aver Time:   1.35 secs. Success rate: 505 / 505
# Aver Time:   1.35 secs. Success rate: 510 / 510
# Aver Time:   1.36 secs. Success rate: 515 / 515
# Aver Time:   1.36 secs. Success rate: 520 / 520
# Aver Time:   1.36 secs. Success rate: 525 / 525
# Aver Time:   1.36 secs. Success rate: 530 / 530
# Aver Time:   1.37 secs. Success rate: 535 / 535
# Aver Time:   1.37 secs. Success rate: 540 / 540
# Aver Time:   1.37 secs. Success rate: 545 / 545
# Aver Time:   1.37 secs. Success rate: 550 / 550
# Aver Time:   1.38 secs. Success rate: 555 / 555
# Aver Time:   1.38 secs. Success rate: 560 / 560
# Aver Time:   1.38 secs. Success rate: 565 / 565
# Aver Time:   1.38 secs. Success rate: 570 / 570
# Aver Time:   1.37 secs. Success rate: 575 / 575
# Aver Time:   1.37 secs. Success rate: 580 / 580
# Aver Time:   1.37 secs. Success rate: 585 / 585
# Aver Time:   1.37 secs. Success rate: 590 / 590
# Aver Time:   1.37 secs. Success rate: 595 / 595
# Aver Time:   1.36 secs. Success rate: 600 / 600
# Aver Time:   1.36 secs. Success rate: 605 / 605
# Aver Time:   1.36 secs. Success rate: 610 / 610
# Aver Time:   1.36 secs. Success rate: 615 / 615
# Aver Time:   1.36 secs. Success rate: 620 / 620
# Aver Time:   1.37 secs. Success rate: 625 / 625
# Aver Time:   1.37 secs. Success rate: 630 / 630
# Aver Time:   1.37 secs. Success rate: 635 / 635
# Aver Time:   1.37 secs. Success rate: 640 / 640
# Aver Time:   1.37 secs. Success rate: 645 / 645
# Aver Time:   1.37 secs. Success rate: 650 / 650
# Aver Time:   1.37 secs. Success rate: 655 / 655
# Aver Time:   1.37 secs. Success rate: 660 / 660
# Aver Time:   1.37 secs. Success rate: 665 / 665
# Aver Time:   1.37 secs. Success rate: 670 / 670
# Aver Time:   1.37 secs. Success rate: 675 / 675
# Aver Time:   1.37 secs. Success rate: 680 / 680
# Aver Time:   1.37 secs. Success rate: 685 / 685
# Aver Time:   1.37 secs. Success rate: 690 / 690
# Aver Time:   1.38 secs. Success rate: 695 / 695
# Aver Time:   1.38 secs. Success rate: 700 / 700
# Aver Time:   1.38 secs. Success rate: 705 / 705
# Aver Time:   1.38 secs. Success rate: 710 / 710
# Aver Time:   1.39 secs. Success rate: 715 / 715
# Aver Time:   1.39 secs. Success rate: 720 / 720
# Aver Time:   1.39 secs. Success rate: 725 / 725
# Aver Time:   1.39 secs. Success rate: 730 / 730
# Aver Time:   1.39 secs. Success rate: 735 / 735
# Aver Time:   1.39 secs. Success rate: 740 / 740
# Aver Time:   1.40 secs. Success rate: 745 / 745
# Aver Time:   1.40 secs. Success rate: 750 / 750
# Aver Time:   1.40 secs. Success rate: 755 / 755
# Aver Time:   1.40 secs. Success rate: 760 / 760
# Aver Time:   1.40 secs. Success rate: 765 / 765
# Aver Time:   1.40 secs. Success rate: 770 / 770
# Aver Time:   1.40 secs. Success rate: 775 / 775
# Aver Time:   1.41 secs. Success rate: 780 / 780
# Aver Time:   1.41 secs. Success rate: 785 / 785
# Aver Time:   1.41 secs. Success rate: 790 / 790
# Aver Time:   1.41 secs. Success rate: 795 / 795
# Aver Time:   1.41 secs. Success rate: 800 / 800
# Aver Time:   1.41 secs. Success rate: 805 / 805
# Aver Time:   1.41 secs. Success rate: 810 / 810
# Aver Time:   1.41 secs. Success rate: 815 / 815
# Aver Time:   1.42 secs. Success rate: 820 / 820
# Aver Time:   1.42 secs. Success rate: 825 / 825
# Aver Time:   1.42 secs. Success rate: 830 / 830
# Aver Time:   1.42 secs. Success rate: 835 / 835
# Aver Time:   1.42 secs. Success rate: 840 / 840
# Aver Time:   1.42 secs. Success rate: 845 / 845
# Aver Time:   1.43 secs. Success rate: 850 / 850
# Aver Time:   1.43 secs. Success rate: 855 / 855
# Aver Time:   1.43 secs. Success rate: 860 / 860
# Aver Time:   1.43 secs. Success rate: 865 / 865
# Aver Time:   1.43 secs. Success rate: 870 / 870
# Aver Time:   1.43 secs. Success rate: 875 / 875
# Aver Time:   1.43 secs. Success rate: 880 / 880
# Aver Time:   1.43 secs. Success rate: 885 / 885
# Aver Time:   1.43 secs. Success rate: 890 / 890
# Aver Time:   1.43 secs. Success rate: 895 / 895
# Aver Time:   1.43 secs. Success rate: 900 / 900
# Aver Time:   1.43 secs. Success rate: 905 / 905
# Aver Time:   1.44 secs. Success rate: 910 / 910
# Aver Time:   1.44 secs. Success rate: 915 / 915
# Aver Time:   1.44 secs. Success rate: 920 / 920
# Aver Time:   1.44 secs. Success rate: 925 / 925
# Aver Time:   1.44 secs. Success rate: 930 / 930
# Aver Time:   1.44 secs. Success rate: 935 / 935
# Aver Time:   1.44 secs. Success rate: 940 / 940
# Aver Time:   1.44 secs. Success rate: 945 / 945
# Aver Time:   1.44 secs. Success rate: 950 / 950
# Aver Time:   1.44 secs. Success rate: 955 / 955
# Aver Time:   1.44 secs. Success rate: 960 / 960
# Aver Time:   1.44 secs. Success rate: 965 / 965
# Aver Time:   1.44 secs. Success rate: 970 / 970
# Aver Time:   1.44 secs. Success rate: 975 / 975
# Aver Time:   1.44 secs. Success rate: 980 / 980
# Aver Time:   1.44 secs. Success rate: 985 / 985
# Aver Time:   1.44 secs. Success rate: 990 / 990
# Aver Time:   1.44 secs. Success rate: 995 / 995
# Aver Time:   1.45 secs. Success rate: 1000 / 1000
# Aver Time:   1.45 secs. Success rate: 1000 / 1000
# 1.0
